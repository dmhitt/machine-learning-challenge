# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
#selected_features = df.drop(['koi_disposition'], axis = 1)
X = df.drop(['koi_disposition'], axis = 1)
X.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
y = df['koi_disposition']
y_names = ['CONFIRMED','FALSE POSITIVE','CANDIDATE']
y.head()
# Out:
# 0         CONFIRMED
# 1    FALSE POSITIVE
# 2    FALSE POSITIVE
# 3         CONFIRMED
# 4         CONFIRMED
# Name: koi_disposition, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((5592, 40), (1399, 40), (5592,), (1399,))

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 2698              1              0              0              0    1.055693
# 3891              0              1              0              0    1.592634
# 3316              0              0              0              0   10.507178
# 3670              0              0              0              0   82.292865
# 4652              1              0              0              1  370.913080
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 2698     2.150000e-05    -2.150000e-05   131.557600           0.01590
# 3891     7.010000e-07    -7.010000e-07   132.328769           0.00050
# 3316     1.082000e-04    -1.082000e-04   139.664320           0.00791
# 3670     1.225000e-03    -1.225000e-03   212.031400           0.01240
# 4652     1.344000e-02    -1.344000e-02   261.188400           0.02050
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 2698          -0.01590  ...            -176      4.561           0.061
# 3891          -0.00050  ...            -227      4.061           0.264
# 3316          -0.00791  ...            -167      4.460           0.117
# 3670          -0.01240  ...             -84      4.467           0.051
# 4652          -0.02050  ...            -171      4.386           0.097
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 2698          -0.050     0.751          0.072         -0.072  291.95761
# 3891          -0.176     1.768          0.477         -0.583  291.76633
# 3316          -0.130     0.865          0.151         -0.113  294.13626
# 3670          -0.119     0.957          0.132         -0.066  281.29581
# 4652          -0.256     1.054          0.397         -0.137  291.13617
#
#             dec  koi_kepmag
# 2698  38.070049      13.203
# 3891  37.097191      14.915
# 3316  41.456692      15.654
# 3670  44.465401      14.828
# 4652  43.476749      13.648
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_scaled = X_minmax.transform(X_train)
X_test_scaled = X_minmax.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train_scaled, y_train)
print(f"Training Data Score: {knn.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {knn.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8742846924177397
# Testing Data Score: 0.8055754110078628

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model

from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors': [3, 5, 7, 9]}
    
grid = GridSearchCV(knn, param_grid, verbose=3, return_train_score=True)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .n_neighbors=3;, score=(train=0.901, test=0.810) total time=   0.1s
# [CV 2/5] END .n_neighbors=3;, score=(train=0.897, test=0.814) total time=   0.1s
# [CV 3/5] END .n_neighbors=3;, score=(train=0.895, test=0.820) total time=   0.1s
# [CV 4/5] END .n_neighbors=3;, score=(train=0.895, test=0.829) total time=   0.1s
# [CV 5/5] END .n_neighbors=3;, score=(train=0.901, test=0.797) total time=   0.1s
# [CV 1/5] END .n_neighbors=5;, score=(train=0.881, test=0.815) total time=   0.1s
# [CV 2/5] END .n_neighbors=5;, score=(train=0.882, test=0.823) total time=   0.1s
# [CV 3/5] END .n_neighbors=5;, score=(train=0.875, test=0.822) total time=   0.1s
# [CV 4/5] END .n_neighbors=5;, score=(train=0.876, test=0.824) total time=   0.1s
# [CV 5/5] END .n_neighbors=5;, score=(train=0.882, test=0.806) total time=   0.1s
# [CV 1/5] END .n_neighbors=7;, score=(train=0.870, test=0.820) total time=   0.1s
# [CV 2/5] END .n_neighbors=7;, score=(train=0.872, test=0.828) total time=   0.1s
# [CV 3/5] END .n_neighbors=7;, score=(train=0.870, test=0.823) total time=   0.1s
# [CV 4/5] END .n_neighbors=7;, score=(train=0.869, test=0.821) total time=   0.1s
# [CV 5/5] END .n_neighbors=7;, score=(train=0.875, test=0.810) total time=   0.1s
# [CV 1/5] END .n_neighbors=9;, score=(train=0.858, test=0.820) total time=   0.1s
# [CV 2/5] END .n_neighbors=9;, score=(train=0.864, test=0.828) total time=   0.1s
# [CV 3/5] END .n_neighbors=9;, score=(train=0.861, test=0.822) total time=   0.1s
# [CV 4/5] END .n_neighbors=9;, score=(train=0.863, test=0.810) total time=   0.1s
# [CV 5/5] END .n_neighbors=9;, score=(train=0.864, test=0.809) total time=   0.1s
# GridSearchCV(estimator=KNeighborsClassifier(n_neighbors=7),
#              param_grid={'n_neighbors': [3, 5, 7, 9]}, return_train_score=True,
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'n_neighbors': 7}
# 0.8206352784318993

# %%
predictions = grid.predict(X_test_scaled)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=y_names))
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.69      0.49      0.58       362
# FALSE POSITIVE       0.60      0.76      0.67       355
#      CANDIDATE       0.98      1.00      0.99       682
#
#       accuracy                           0.81      1399
#      macro avg       0.76      0.75      0.74      1399
#   weighted avg       0.81      0.81      0.80      1399

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'KNN.sav'
joblib.dump(knn, filename)
# Out:
# ['KNN.sav']
