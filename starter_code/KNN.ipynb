# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
#selected_features = df.drop(['koi_disposition'], axis = 1)
X = df.drop(['koi_disposition'], axis = 1)
X.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
y = df['koi_disposition']
y_names = ['CONFIRMED','FALSE POSITIVE','CANDIDATE']
y.head()
# Out:
# 0         CONFIRMED
# 1    FALSE POSITIVE
# 2    FALSE POSITIVE
# 3         CONFIRMED
# 4         CONFIRMED
# Name: koi_disposition, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((5592, 40), (1399, 40), (5592,), (1399,))

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 5183              0              1              0              0    8.752914
# 5181              0              0              0              0  406.496216
# 4640              0              0              0              0  182.453195
# 1601              0              0              0              0   40.990500
# 3169              0              0              0              0   12.003678
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 5183         0.000003        -0.000003   138.724933           0.00026
# 5181         0.007638        -0.007638   325.902500           0.01740
# 4640         0.004504        -0.004504   282.544500           0.01750
# 1601         0.000440        -0.000440   132.413600           0.00852
# 3169         0.000101        -0.000101   134.710070           0.00664
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 5183          -0.00026  ...            -327      3.856           0.315
# 5181          -0.01740  ...            -159      4.525           0.035
# 4640          -0.01750  ...            -180      4.483           0.055
# 1601          -0.00852  ...             -70      4.170           0.176
# 3169          -0.00664  ...            -131      4.654           0.056
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 5183          -0.135     2.624          0.531         -1.061  298.81647
# 5181          -0.303     0.884          0.383         -0.073  295.56683
# 4640          -0.288     0.927          0.366         -0.089  289.02255
# 1601          -0.095     1.410          0.246         -0.270  287.83847
# 3169          -0.024     0.594          0.050         -0.056  291.69516
#
#             dec  koi_kepmag
# 5183  43.673321      11.961
# 5181  49.378029      13.893
# 4640  45.926022      13.872
# 1601  43.153229      15.272
# 3169  49.187859      15.675
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_scaled = X_minmax.transform(X_train)
X_test_scaled = X_minmax.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train_scaled, y_train)
print(f"Training Data Score: {knn.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {knn.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.869277539341917
# Testing Data Score: 0.8177269478198713

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model

from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors': [3, 5, 7, 9]}
    
grid = GridSearchCV(knn, param_grid, verbose=3, return_train_score=True)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .n_neighbors=3;, score=(train=0.902, test=0.807) total time=   0.1s
# [CV 2/5] END .n_neighbors=3;, score=(train=0.894, test=0.819) total time=   0.1s
# [CV 3/5] END .n_neighbors=3;, score=(train=0.900, test=0.807) total time=   0.1s
# [CV 4/5] END .n_neighbors=3;, score=(train=0.897, test=0.791) total time=   0.1s
# [CV 5/5] END .n_neighbors=3;, score=(train=0.897, test=0.816) total time=   0.1s
# [CV 1/5] END .n_neighbors=5;, score=(train=0.878, test=0.810) total time=   0.1s
# [CV 2/5] END .n_neighbors=5;, score=(train=0.879, test=0.815) total time=   0.1s
# [CV 3/5] END .n_neighbors=5;, score=(train=0.876, test=0.798) total time=   0.1s
# [CV 4/5] END .n_neighbors=5;, score=(train=0.880, test=0.808) total time=   0.1s
# [CV 5/5] END .n_neighbors=5;, score=(train=0.873, test=0.811) total time=   0.1s
# [CV 1/5] END .n_neighbors=7;, score=(train=0.865, test=0.818) total time=   0.1s
# [CV 2/5] END .n_neighbors=7;, score=(train=0.867, test=0.815) total time=   0.1s
# [CV 3/5] END .n_neighbors=7;, score=(train=0.868, test=0.810) total time=   0.1s
# [CV 4/5] END .n_neighbors=7;, score=(train=0.871, test=0.814) total time=   0.1s
# [CV 5/5] END .n_neighbors=7;, score=(train=0.861, test=0.819) total time=   0.1s
# [CV 1/5] END .n_neighbors=9;, score=(train=0.860, test=0.810) total time=   0.1s
# [CV 2/5] END .n_neighbors=9;, score=(train=0.860, test=0.817) total time=   0.1s
# [CV 3/5] END .n_neighbors=9;, score=(train=0.861, test=0.812) total time=   0.1s
# [CV 4/5] END .n_neighbors=9;, score=(train=0.861, test=0.825) total time=   0.1s
# [CV 5/5] END .n_neighbors=9;, score=(train=0.852, test=0.830) total time=   0.1s
# GridSearchCV(estimator=KNeighborsClassifier(n_neighbors=7),
#              param_grid={'n_neighbors': [3, 5, 7, 9]}, return_train_score=True,
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'n_neighbors': 9}
# 0.8186714754580582

# %%
predictions = grid.predict(X_test_scaled)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=y_names))
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.66      0.53      0.59       335
# FALSE POSITIVE       0.64      0.74      0.69       365
#      CANDIDATE       0.99      1.00      0.99       699
#
#       accuracy                           0.82      1399
#      macro avg       0.76      0.76      0.76      1399
#   weighted avg       0.82      0.82      0.82      1399

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'Dinnara_Hitt_KNN.sav'
joblib.dump(knn, filename)
# Out:
# ['Dinnara_Hitt_KNN.sav']
