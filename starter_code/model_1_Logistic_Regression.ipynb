# %%
# Update sklearn to prevent version mismatches
#!pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
#!pip install joblib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0   54.418383     2.479000e-04    -2.479000e-04
# 1                 0   19.899140     1.490000e-05    -1.490000e-05
# 2                 0    1.736952     2.630000e-07    -2.630000e-07
# 3                 0    2.525592     3.760000e-06    -3.760000e-06
# 4                 0    4.134435     1.050000e-05    -1.050000e-05
# ...             ...         ...              ...              ...
# 6986              1    8.589871     1.846000e-04    -1.846000e-04
# 6987              0    0.527699     1.160000e-07    -1.160000e-07
# 6988              0    1.739849     1.780000e-05    -1.780000e-05
# 6989              0    0.681402     2.430000e-06    -2.430000e-06
# 6990              1    4.856035     6.360000e-05    -6.360000e-05
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  \
# 0      162.513840          0.003520  ...             -81      4.467
# 1      175.850252          0.000581  ...            -176      4.544
# 2      170.307565          0.000115  ...            -174      4.564
# 3      171.595550          0.001130  ...            -211      4.438
# 4      172.979370          0.001900  ...            -232      4.486
# ...           ...               ...  ...             ...        ...
# 6986   132.016100          0.015700  ...            -152      4.296
# 6987   131.705093          0.000170  ...            -166      4.529
# 6988   133.001270          0.007690  ...            -220      4.444
# 6989   132.181750          0.002850  ...            -236      4.447
# 6990   135.993300          0.010800  ...            -225      4.385
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0              0.064          -0.096     0.927          0.105         -0.061
# 1              0.044          -0.176     0.868          0.233         -0.078
# 2              0.053          -0.168     0.791          0.201         -0.067
# 3              0.070          -0.210     1.046          0.334         -0.133
# 4              0.054          -0.229     0.972          0.315         -0.105
# ...              ...             ...       ...            ...            ...
# 6986           0.231          -0.189     1.088          0.313         -0.228
# 6987           0.035          -0.196     0.903          0.237         -0.079
# 6988           0.056          -0.224     1.031          0.341         -0.114
# 6989           0.056          -0.224     1.041          0.341         -0.114
# 6990           0.054          -0.216     1.193          0.410         -0.137
#
#              ra        dec  koi_kepmag
# 0     291.93423  48.141651      15.347
# 1     297.00482  48.134129      15.436
# 2     285.53461  48.285210      15.597
# 3     288.75488  48.226200      15.509
# 4     296.28613  48.224670      15.714
# ...         ...        ...         ...
# 6986  298.74921  46.973351      14.478
# 6987  297.18875  47.093819      14.082
# 6988  286.50937  47.163219      14.757
# 6989  294.16489  47.176281      15.385
# 6990  297.00977  47.121021      14.826
#
# [6991 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
#selected_features = df.drop(['koi_disposition'], axis = 1)
X = df.drop(['koi_disposition'], axis = 1)

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
y = df['koi_disposition']
y
#df.koi_disposition.value_counts()
# Out:
# 0            CONFIRMED
# 1       FALSE POSITIVE
# 2       FALSE POSITIVE
# 3            CONFIRMED
# 4            CONFIRMED
#              ...
# 6986    FALSE POSITIVE
# 6987    FALSE POSITIVE
# 6988         CANDIDATE
# 6989    FALSE POSITIVE
# 6990    FALSE POSITIVE
# Name: koi_disposition, Length: 6991, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
#y_train
# Out:
# ((5592, 40), (1399, 40), (5592,), (1399,))

# %%
X_train
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 1656              0              1              1              0    5.460918
# 3409              0              0              1              0    1.190874
# 5500              0              0              0              0    8.502077
# 2474              0              0              0              0   21.347366
# 841               0              0              0              0    7.061173
# ...             ...            ...            ...            ...         ...
# 2368              0              0              1              1    5.910377
# 6636              0              0              1              1    0.933749
# 2418              1              0              0              0   43.501748
# 3363              0              0              0              0   25.861606
# 4863              1              0              0              0  149.356804
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 1656         0.000025        -0.000025    131.66849           0.00432
# 3409         0.000013        -0.000013    131.71838           0.00780
# 5500         0.000093        -0.000093    132.36121           0.00940
# 2474         0.000048        -0.000048    171.73531           0.00192
# 841          0.000012        -0.000012    136.27344           0.00129
# ...               ...              ...          ...               ...
# 2368         0.000022        -0.000022    171.15166           0.00281
# 6636         0.000017        -0.000017    132.45340           0.01790
# 2418         0.002151        -0.002151    164.28590           0.03020
# 3363         0.000857        -0.000857    140.20480           0.02880
# 4863         0.005784        -0.005784    278.13870           0.02460
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 1656          -0.00432  ...            -209      4.465           0.067
# 3409          -0.00780  ...            -155      4.464           0.105
# 5500          -0.00940  ...            -131      4.570           0.066
# 2474          -0.00192  ...             -72      4.324           0.154
# 841           -0.00129  ...             -88      4.761           0.038
# ...                ...  ...             ...        ...             ...
# 2368          -0.00281  ...            -165      4.443           0.136
# 6636          -0.01790  ...            -179      4.554           0.036
# 2418          -0.03020  ...             -54      2.936           0.013
# 3363          -0.02880  ...            -201      4.524           0.052
# 4863          -0.02460  ...            -241      3.842           0.386
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 1656          -0.189     0.930          0.253         -0.108  295.78381
# 3409          -0.105     0.888          0.122         -0.100  294.59283
# 5500          -0.044     0.715          0.062         -0.069  288.29715
# 2474          -0.112     1.071          0.180         -0.180  295.00281
# 841           -0.035     0.490          0.030         -0.037  283.13547
# ...              ...       ...            ...            ...        ...
# 2368          -0.204     0.867          0.204         -0.136  293.83701
# 6636          -0.192     0.846          0.235         -0.078  292.22760
# 2418          -0.012     6.221          0.559         -0.509  285.67288
# 3363          -0.208     0.884          0.260         -0.087  289.44324
# 4863          -0.146     2.203          0.639         -0.943  295.40790
#
#             dec  koi_kepmag
# 1656  43.182400      14.332
# 3409  45.287720      15.280
# 5500  47.560040      14.755
# 2474  46.987331      14.415
# 841   43.657051      14.390
# ...         ...         ...
# 2368  40.412750      14.276
# 6636  47.746262      15.767
# 2418  44.116730      12.495
# 3363  40.253529      15.183
# 4863  45.535233      13.825
#
# [5592 rows x 40 columns]

# %%
y_train
# Out:
# 1656    FALSE POSITIVE
# 3409    FALSE POSITIVE
# 5500         CANDIDATE
# 2474         CONFIRMED
# 841          CONFIRMED
#              ...
# 2368    FALSE POSITIVE
# 6636    FALSE POSITIVE
# 2418    FALSE POSITIVE
# 3363         CANDIDATE
# 4863    FALSE POSITIVE
# Name: koi_disposition, Length: 5592, dtype: object

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)
#y_minmax = MinMaxScaler().fit(y_train)

X_train_scaled = X_minmax.transform(X_train)
X_test_scaled = X_minmax.transform(X_test)
#y_train = y_minmax.transform(y_train)
#y_test = y_minmax.transform(y_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='liblinear', random_state=0)
classifier
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %%
classifier.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %%
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8447782546494993
# Testing Data Score: 0.82987848463188

# %%
#Dinnara
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'FALSE POSITIVE']
# First 10 Actual labels: ['FALSE POSITIVE', 'FALSE POSITIVE', 'CANDIDATE', 'CONFIRMED', 'CANDIDATE', 'CANDIDATE', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CANDIDATE', 'FALSE POSITIVE']

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#           Prediction          Actual
# 0     FALSE POSITIVE  FALSE POSITIVE
# 1     FALSE POSITIVE  FALSE POSITIVE
# 2     FALSE POSITIVE       CANDIDATE
# 3     FALSE POSITIVE       CONFIRMED
# 4     FALSE POSITIVE       CANDIDATE
# ...              ...             ...
# 1394  FALSE POSITIVE  FALSE POSITIVE
# 1395  FALSE POSITIVE       CANDIDATE
# 1396  FALSE POSITIVE       CANDIDATE
# 1397  FALSE POSITIVE  FALSE POSITIVE
# 1398  FALSE POSITIVE  FALSE POSITIVE
#
# [1399 rows x 2 columns]

# %%
classifier.classes_
# Out:
# array(['CANDIDATE', 'CONFIRMED', 'FALSE POSITIVE'], dtype=object)

# %%
classifier.intercept_
# Out:
# array([ 1.16219737, -1.61689683, -0.0239114 ])

# %%
classifier.coef_
# Out:
# array([[-6.35222442, -3.91662916, -4.76935965, -3.63623377,  3.41655985,
#          0.87738359,  0.28481377, -0.50027753,  3.11785526, -1.95565789,
#          0.09411305,  1.80677622,  1.28826837, -1.59720841,  3.70184635,
#         -2.53964898, -0.76955029,  0.22204938,  0.94014799, -0.01982479,
#         -0.04209581,  1.18217169,  1.86576616,  0.09383567,  0.1186048 ,
#          1.0373654 , -2.46730643, -1.05423   , -0.27924201,  3.27044232,
#         -0.5665383 , -1.65100471,  0.74755586, -1.63096045,  0.45099626,
#          0.86210963,  0.90443706,  0.47980147, -0.5777631 ,  0.16196985],
#        [-2.72607621, -3.48940699, -3.46797051, -2.9231687 , -3.63755628,
#         -1.80491196,  0.18801513,  0.47333901, -4.21363553,  2.59673869,
#         -0.5871754 , -2.72899615, -1.39986264,  1.22779196, -4.59346987,
#          2.97657304, -2.35960306, -0.47773854, -1.13915829, -0.12978954,
#         -0.14783263, -1.50005641, -2.36577717, -0.11535599, -0.14174058,
#         -1.47775203,  1.14379199,  1.25277263,  0.34071633, -3.95548142,
#          0.88571074,  1.71042981, -1.05255744,  1.80372895, -0.7155733 ,
#         -1.28120817, -1.19024694, -0.5338816 ,  0.62839681, -0.24025291],
#        [ 7.46434524,  6.99408467,  7.57610314,  6.5621032 ,  0.92340056,
#          0.636091  , -0.6600024 ,  0.33642043,  0.37720565, -0.40111705,
#          0.35955602,  0.87897058, -0.21324457,  0.36864275,  0.49882725,
#         -0.52273866,  2.59994801,  0.23199877, -0.25591017,  0.06946884,
#          0.09087192, -0.08160957,  0.45855864,  0.01303762,  0.01501668,
#         -0.02703898,  0.87253721, -1.56386394,  0.3366367 ,  1.9219605 ,
#         -1.07497046, -0.66389023,  0.48333149, -1.76743087,  0.18590291,
#          0.39322468, -0.16441622,  0.36419743, -0.34307769,  0.52272725]])

# %%
classifier.predict(X)
# Out:
# array(['FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE', ...,
#        'FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE'], dtype=object)

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='liblinear', random_state=0)

# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10, 50]}
    
grid = GridSearchCV(classifier, param_grid, verbose=3, return_train_score=True)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END ...........C=1;, score=(train=0.844, test=0.841) total time=   0.1s
# [CV 2/5] END ...........C=1;, score=(train=0.840, test=0.830) total time=   0.0s
# [CV 3/5] END ...........C=1;, score=(train=0.844, test=0.827) total time=   0.0s
# [CV 4/5] END ...........C=1;, score=(train=0.844, test=0.842) total time=   0.0s
# [CV 5/5] END ...........C=1;, score=(train=0.839, test=0.853) total time=   0.0s
# [CV 1/5] END ...........C=5;, score=(train=0.865, test=0.855) total time=   0.1s
# [CV 2/5] END ...........C=5;, score=(train=0.859, test=0.861) total time=   0.1s
# [CV 3/5] END ...........C=5;, score=(train=0.861, test=0.850) total time=   0.1s
# [CV 4/5] END ...........C=5;, score=(train=0.862, test=0.865) total time=   0.0s
# [CV 5/5] END ...........C=5;, score=(train=0.859, test=0.873) total time=   0.1s
# [CV 1/5] END ..........C=10;, score=(train=0.873, test=0.861) total time=   0.1s
# [CV 2/5] END ..........C=10;, score=(train=0.867, test=0.871) total time=   0.1s
# [CV 3/5] END ..........C=10;, score=(train=0.867, test=0.860) total time=   0.1s
# [CV 4/5] END ..........C=10;, score=(train=0.868, test=0.872) total time=   0.1s
# [CV 5/5] END ..........C=10;, score=(train=0.868, test=0.877) total time=   0.1s
# [CV 1/5] END ..........C=50;, score=(train=0.881, test=0.873) total time=   0.1s
# [CV 2/5] END ..........C=50;, score=(train=0.879, test=0.889) total time=   0.1s
# [CV 3/5] END ..........C=50;, score=(train=0.884, test=0.867) total time=   0.1s
# [CV 4/5] END ..........C=50;, score=(train=0.880, test=0.879) total time=   0.1s
# [CV 5/5] END ..........C=50;, score=(train=0.883, test=0.877) total time=   0.1s
# GridSearchCV(estimator=LogisticRegression(random_state=0, solver='liblinear'),
#              param_grid={'C': [1, 5, 10, 50]}, return_train_score=True,
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 50}
# 0.8769656014746108

# %%
#Dinnara
predictions = grid.predict(X_test)

# %%
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CONFIRMED' 'CONFIRMED' 'FALSE POSITIVE' 'CONFIRMED'
#  'FALSE POSITIVE']
# First 10 Actual labels: ['FALSE POSITIVE', 'FALSE POSITIVE', 'CANDIDATE', 'CONFIRMED', 'CANDIDATE', 'CANDIDATE', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CANDIDATE', 'FALSE POSITIVE']

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=["blue", "red", "white"]))
# Out:
#               precision    recall  f1-score   support
#
#         blue       0.00      0.00      0.00       335
#          red       0.28      0.61      0.38       374
#        white       0.58      0.48      0.52       690
#
#     accuracy                           0.40      1399
#    macro avg       0.28      0.36      0.30      1399
# weighted avg       0.36      0.40      0.36      1399

# %%
results = pd.DataFrame(grid.cv_results_)
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.044598      0.008864         0.001223        0.000539       1
# 1       0.051148      0.001439         0.000954        0.000063       5
# 2       0.060693      0.003499         0.000986        0.000129      10
# 3       0.089033      0.003554         0.001090        0.000103      50
#
#       params  split0_test_score  split1_test_score  split2_test_score  \
# 0   {'C': 1}           0.840929           0.830206           0.827370
# 1   {'C': 5}           0.855228           0.860590           0.849732
# 2  {'C': 10}           0.860590           0.871314           0.859571
# 3  {'C': 50}           0.873101           0.889187           0.866726
#
#    split3_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0           0.841682  ...         0.838699        0.009250                4
# 1           0.864937  ...         0.860695        0.007990                3
# 2           0.872093  ...         0.868026        0.006739                2
# 3           0.879249  ...         0.876966        0.007410                1
#
#    split0_train_score  split1_train_score  split2_train_score  \
# 0            0.843505            0.840152            0.843764
# 1            0.864968            0.859378            0.860975
# 2            0.872792            0.867203            0.867009
# 3            0.881064            0.878605            0.883549
#
#    split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0            0.844211            0.839070          0.842141         0.002106
# 1            0.861869            0.859410          0.861320         0.002056
# 2            0.868127            0.867903          0.868607         0.002134
# 3            0.880420            0.882879          0.881304         0.001769
#
# [4 rows x 21 columns]

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-7ffc35e2dc82> in <module>
#       5 import joblib
#       6 filename = 'your_name.sav'
# ----> 7 joblib.dump(your_model, filename)
#
# NameError: name 'your_model' is not defined
