# %%
# Update sklearn to prevent version mismatches
#!pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
#!pip install joblib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0   54.418383     2.479000e-04    -2.479000e-04
# 1                 0   19.899140     1.490000e-05    -1.490000e-05
# 2                 0    1.736952     2.630000e-07    -2.630000e-07
# 3                 0    2.525592     3.760000e-06    -3.760000e-06
# 4                 0    4.134435     1.050000e-05    -1.050000e-05
# ...             ...         ...              ...              ...
# 6986              1    8.589871     1.846000e-04    -1.846000e-04
# 6987              0    0.527699     1.160000e-07    -1.160000e-07
# 6988              0    1.739849     1.780000e-05    -1.780000e-05
# 6989              0    0.681402     2.430000e-06    -2.430000e-06
# 6990              1    4.856035     6.360000e-05    -6.360000e-05
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  \
# 0      162.513840          0.003520  ...             -81      4.467
# 1      175.850252          0.000581  ...            -176      4.544
# 2      170.307565          0.000115  ...            -174      4.564
# 3      171.595550          0.001130  ...            -211      4.438
# 4      172.979370          0.001900  ...            -232      4.486
# ...           ...               ...  ...             ...        ...
# 6986   132.016100          0.015700  ...            -152      4.296
# 6987   131.705093          0.000170  ...            -166      4.529
# 6988   133.001270          0.007690  ...            -220      4.444
# 6989   132.181750          0.002850  ...            -236      4.447
# 6990   135.993300          0.010800  ...            -225      4.385
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0              0.064          -0.096     0.927          0.105         -0.061
# 1              0.044          -0.176     0.868          0.233         -0.078
# 2              0.053          -0.168     0.791          0.201         -0.067
# 3              0.070          -0.210     1.046          0.334         -0.133
# 4              0.054          -0.229     0.972          0.315         -0.105
# ...              ...             ...       ...            ...            ...
# 6986           0.231          -0.189     1.088          0.313         -0.228
# 6987           0.035          -0.196     0.903          0.237         -0.079
# 6988           0.056          -0.224     1.031          0.341         -0.114
# 6989           0.056          -0.224     1.041          0.341         -0.114
# 6990           0.054          -0.216     1.193          0.410         -0.137
#
#              ra        dec  koi_kepmag
# 0     291.93423  48.141651      15.347
# 1     297.00482  48.134129      15.436
# 2     285.53461  48.285210      15.597
# 3     288.75488  48.226200      15.509
# 4     296.28613  48.224670      15.714
# ...         ...        ...         ...
# 6986  298.74921  46.973351      14.478
# 6987  297.18875  47.093819      14.082
# 6988  286.50937  47.163219      14.757
# 6989  294.16489  47.176281      15.385
# 6990  297.00977  47.121021      14.826
#
# [6991 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
#selected_features = df.drop(['koi_disposition'], axis = 1)
X = df.drop(['koi_disposition'], axis = 1)

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
y = df['koi_disposition']
y_names = ['CONFIRMED','FALSE POSITIVE','CANDIDATE']
y
#df.koi_disposition.value_counts()
# Out:
# 0            CONFIRMED
# 1       FALSE POSITIVE
# 2       FALSE POSITIVE
# 3            CONFIRMED
# 4            CONFIRMED
#              ...
# 6986    FALSE POSITIVE
# 6987    FALSE POSITIVE
# 6988         CANDIDATE
# 6989    FALSE POSITIVE
# 6990    FALSE POSITIVE
# Name: koi_disposition, Length: 6991, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
#y_train
# Out:
# ((5592, 40), (1399, 40), (5592,), (1399,))

# %%
X_train
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 1967              0              0              0              0    8.512038
# 6072              0              1              0              0   27.818924
# 5539              1              0              0              0    3.550271
# 380               0              1              1              1    1.613001
# 6383              0              1              0              0   17.511915
# ...             ...            ...            ...            ...         ...
# 3086              0              1              1              1    0.512583
# 6699              0              0              0              0    4.631891
# 1451              0              0              0              0    4.457433
# 679               0              0              0              0   15.749586
# 4734              0              0              0              0  509.997402
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 1967         0.000006        -0.000006   174.909816           0.00060
# 6072         0.000044        -0.000044   158.102820           0.00126
# 5539         0.000046        -0.000046   133.771100           0.01090
# 380          0.000009        -0.000009   178.528460           0.00496
# 6383         0.000096        -0.000096   134.390650           0.00457
# ...               ...              ...          ...               ...
# 3086         0.000003        -0.000003   131.775710           0.00456
# 6699         0.000115        -0.000115   133.707300           0.02220
# 1451         0.000017        -0.000017   132.160060           0.00345
# 679          0.000047        -0.000047   150.245790           0.00231
# 4734         0.003256        -0.003256   276.731220           0.00391
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 1967          -0.00060  ...            -126      4.538           0.021
# 6072          -0.00126  ...            -201      4.513           0.054
# 5539          -0.01090  ...            -199      4.581           0.036
# 380           -0.00496  ...            -182      4.223           0.282
# 6383          -0.00457  ...             -96      1.786           0.255
# ...                ...  ...             ...        ...             ...
# 3086          -0.00456  ...            -232      4.471           0.056
# 6699          -0.02220  ...            -177      4.532           0.036
# 1451          -0.00345  ...            -134      4.644           0.052
# 679           -0.00231  ...            -216      4.454           0.056
# 4734          -0.00391  ...            -157      4.540           0.066
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 1967          -0.119     0.881          0.123         -0.044  287.08997
# 6072          -0.216     0.915          0.286         -0.095  286.27698
# 5539          -0.135     0.800          0.164         -0.070  286.30902
# 380           -0.188     1.205          0.368         -0.335  300.32898
# 6383          -0.255    20.888         10.581         -4.535  292.92682
# ...              ...       ...            ...            ...        ...
# 3086          -0.224     0.999          0.333         -0.111  295.46341
# 6699          -0.204     0.887          0.259         -0.086  295.50128
# 1451          -0.028     0.612          0.052         -0.052  283.12103
# 679           -0.210     1.025          0.332         -0.111  285.43552
# 4734          -0.157     0.756          0.130         -0.077  297.50830
#
#             dec  koi_kepmag
# 1967  41.373878      12.549
# 6072  43.339142      15.325
# 5539  49.623871      15.810
# 380   44.151119      13.945
# 6383  39.613361       9.242
# ...         ...         ...
# 3086  46.011230      15.484
# 6699  45.433979      14.272
# 1451  43.525639      14.374
# 679   45.976021      15.300
# 4734  43.710949      14.150
#
# [5592 rows x 40 columns]

# %%
y_train
# Out:
# 1967         CONFIRMED
# 6072    FALSE POSITIVE
# 5539    FALSE POSITIVE
# 380     FALSE POSITIVE
# 6383    FALSE POSITIVE
#              ...
# 3086    FALSE POSITIVE
# 6699         CANDIDATE
# 1451         CONFIRMED
# 679          CONFIRMED
# 4734         CONFIRMED
# Name: koi_disposition, Length: 5592, dtype: object

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)
#y_minmax = MinMaxScaler().fit(y_train)

X_train_scaled = X_minmax.transform(X_train)
X_test_scaled = X_minmax.transform(X_test)
#y_train = y_minmax.transform(y_train)
#y_test = y_minmax.transform(y_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='liblinear', random_state=0, multi_class ='ovr')
# 'multi_class' : ['auto', 'ovr', 'multinomial']
classifier
# Out:
# LogisticRegression(multi_class='ovr', random_state=0, solver='liblinear')

# %%
classifier.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(multi_class='ovr', random_state=0, solver='liblinear')

# %%
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8433476394849786
# Testing Data Score: 0.8498927805575411

# %%
#Dinnara
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'FALSE POSITIVE']
# First 10 Actual labels: ['FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE', 'CANDIDATE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE', 'FALSE POSITIVE']

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#           Prediction          Actual
# 0          CONFIRMED  FALSE POSITIVE
# 1     FALSE POSITIVE       CONFIRMED
# 2     FALSE POSITIVE  FALSE POSITIVE
# 3     FALSE POSITIVE       CANDIDATE
# 4     FALSE POSITIVE       CANDIDATE
# ...              ...             ...
# 1394  FALSE POSITIVE       CONFIRMED
# 1395  FALSE POSITIVE  FALSE POSITIVE
# 1396  FALSE POSITIVE  FALSE POSITIVE
# 1397  FALSE POSITIVE  FALSE POSITIVE
# 1398  FALSE POSITIVE       CONFIRMED
#
# [1399 rows x 2 columns]

# %%
classifier.classes_
# Out:
# array(['CANDIDATE', 'CONFIRMED', 'FALSE POSITIVE'], dtype=object)

# %%
classifier.intercept_
# Out:
# array([ 1.19164312, -1.53540565, -0.1462686 ])

# %%
classifier.coef_
# Out:
# array([[-6.32923588, -3.93234565, -4.76194232, -3.62567918,  2.92218591,
#          0.71559088,  0.47605223, -0.40727131,  3.19285514, -2.00121202,
#          0.22186404,  1.6478479 ,  1.00703579, -2.01644982,  3.67314886,
#         -2.48150575, -0.48703196,  0.00929527,  1.18234785, -0.02437496,
#         -0.02985988,  1.2176812 ,  1.97868242,  0.07726263,  0.08610855,
#          1.08016418, -2.39984955, -1.25307063, -0.48650008,  3.15886058,
#         -0.69016557, -1.61034589,  0.54699043, -1.83066318,  0.44315006,
#          0.81832149,  0.92684562,  0.50337156, -0.43678625,  0.10323399],
#        [-2.63507411, -3.70330126, -3.24282599, -2.69011126, -3.60105271,
#         -1.56959049,  0.03418485,  0.47952318, -4.23057047,  2.69516483,
#         -0.53152082, -2.53977077, -1.3457501 ,  1.51441541, -4.46200712,
#          2.92660148, -1.68954181, -0.02763553, -1.50777012, -0.05736838,
#         -0.10087386, -1.50029893, -2.7539021 , -0.09066849, -0.11804197,
#         -1.42397259,  0.9409842 ,  1.47614766,  0.58855715, -3.95360825,
#          1.15175273,  1.50887599, -0.94211327,  1.90284761, -0.67899757,
#         -1.22932313, -1.12229466, -0.60465297,  0.48194676, -0.05246725],
#        [ 7.29045294,  7.16456468,  7.40467653,  6.43260265,  1.53984377,
#          0.41925825, -0.56552686,  0.26086989,  0.36950929, -0.51577789,
#          0.29751938,  0.85100518, -0.18791003,  0.45371492,  0.40059338,
#         -0.54686198,  1.94311778,  0.01491323, -0.16118183,  0.05813435,
#          0.08484159, -0.18513439,  0.65016233,  0.00775993,  0.02278461,
#         -0.14307862,  1.02280801, -1.47027344,  0.4069627 ,  2.08085584,
#         -1.24125106, -0.52511796,  0.61050345, -1.45781674,  0.15270172,
#          0.37781752, -0.27073424,  0.5722413 , -0.26052972,  0.21407322]])

# %%
classifier.predict(X)
# Out:
# array(['FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE', ...,
#        'FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE'], dtype=object)

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10, 50], 
              'solver' : ['newton-cg', 'liblinear'],
              'multi_class' : ['auto', 'ovr'] }
    
grid = GridSearchCV(classifier, param_grid, verbose=3, return_train_score=True)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END C=1, multi_class=auto, solver=newton-cg;, score=(train=0.848, test=0.853) total time=   0.1s
# [CV 2/5] END C=1, multi_class=auto, solver=newton-cg;, score=(train=0.850, test=0.845) total time=   0.1s
# [CV 3/5] END C=1, multi_class=auto, solver=newton-cg;, score=(train=0.852, test=0.843) total time=   0.1s
# [CV 4/5] END C=1, multi_class=auto, solver=newton-cg;, score=(train=0.847, test=0.858) total time=   0.1s
# [CV 5/5] END C=1, multi_class=auto, solver=newton-cg;, score=(train=0.849, test=0.846) total time=   0.1s
# [CV 1/5] END C=1, multi_class=auto, solver=liblinear;, score=(train=0.840, test=0.844) total time=   0.0s
# [CV 2/5] END C=1, multi_class=auto, solver=liblinear;, score=(train=0.840, test=0.836) total time=   0.0s
# [CV 3/5] END C=1, multi_class=auto, solver=liblinear;, score=(train=0.840, test=0.830) total time=   0.0s
# [CV 4/5] END C=1, multi_class=auto, solver=liblinear;, score=(train=0.836, test=0.846) total time=   0.0s
# [CV 5/5] END C=1, multi_class=auto, solver=liblinear;, score=(train=0.839, test=0.835) total time=   0.0s
# [CV 1/5] END C=1, multi_class=ovr, solver=newton-cg;, score=(train=0.839, test=0.840) total time=   0.1s
# [CV 2/5] END C=1, multi_class=ovr, solver=newton-cg;, score=(train=0.841, test=0.835) total time=   0.2s
# [CV 3/5] END C=1, multi_class=ovr, solver=newton-cg;, score=(train=0.843, test=0.832) total time=   0.1s
# [CV 4/5] END C=1, multi_class=ovr, solver=newton-cg;, score=(train=0.836, test=0.850) total time=   0.1s
# [CV 5/5] END C=1, multi_class=ovr, solver=newton-cg;, score=(train=0.841, test=0.835) total time=   0.1s
# [CV 1/5] END C=1, multi_class=ovr, solver=liblinear;, score=(train=0.840, test=0.844) total time=   0.0s
# [CV 2/5] END C=1, multi_class=ovr, solver=liblinear;, score=(train=0.840, test=0.836) total time=   0.0s
# [CV 3/5] END C=1, multi_class=ovr, solver=liblinear;, score=(train=0.840, test=0.830) total time=   0.0s
# [CV 4/5] END C=1, multi_class=ovr, solver=liblinear;, score=(train=0.836, test=0.846) total time=   0.0s
# [CV 5/5] END C=1, multi_class=ovr, solver=liblinear;, score=(train=0.839, test=0.835) total time=   0.0s
# [CV 1/5] END C=5, multi_class=auto, solver=newton-cg;, score=(train=0.866, test=0.873) total time=   0.2s
# [CV 2/5] END C=5, multi_class=auto, solver=newton-cg;, score=(train=0.869, test=0.861) total time=   0.2s
# [CV 3/5] END C=5, multi_class=auto, solver=newton-cg;, score=(train=0.869, test=0.852) total time=   0.2s
# [CV 4/5] END C=5, multi_class=auto, solver=newton-cg;, score=(train=0.863, test=0.878) total time=   0.2s
# [CV 5/5] END C=5, multi_class=auto, solver=newton-cg;, score=(train=0.867, test=0.867) total time=   0.2s
# [CV 1/5] END C=5, multi_class=auto, solver=liblinear;, score=(train=0.855, test=0.865) total time=   0.1s
# [CV 2/5] END C=5, multi_class=auto, solver=liblinear;, score=(train=0.858, test=0.851) total time=   0.1s
# [CV 3/5] END C=5, multi_class=auto, solver=liblinear;, score=(train=0.859, test=0.848) total time=   0.1s
# [CV 4/5] END C=5, multi_class=auto, solver=liblinear;, score=(train=0.852, test=0.867) total time=   0.1s
# [CV 5/5] END C=5, multi_class=auto, solver=liblinear;, score=(train=0.859, test=0.854) total time=   0.1s
# [CV 1/5] END C=5, multi_class=ovr, solver=newton-cg;, score=(train=0.856, test=0.864) total time=   0.1s
# [CV 2/5] END C=5, multi_class=ovr, solver=newton-cg;, score=(train=0.858, test=0.845) total time=   0.1s
# [CV 3/5] END C=5, multi_class=ovr, solver=newton-cg;, score=(train=0.859, test=0.846) total time=   0.1s
# [CV 4/5] END C=5, multi_class=ovr, solver=newton-cg;, score=(train=0.852, test=0.868) total time=   0.1s
# [CV 5/5] END C=5, multi_class=ovr, solver=newton-cg;, score=(train=0.858, test=0.857) total time=   0.1s
# [CV 1/5] END C=5, multi_class=ovr, solver=liblinear;, score=(train=0.855, test=0.865) total time=   0.1s
# [CV 2/5] END C=5, multi_class=ovr, solver=liblinear;, score=(train=0.858, test=0.851) total time=   0.1s
# [CV 3/5] END C=5, multi_class=ovr, solver=liblinear;, score=(train=0.859, test=0.848) total time=   0.1s
# [CV 4/5] END C=5, multi_class=ovr, solver=liblinear;, score=(train=0.852, test=0.867) total time=   0.1s
# [CV 5/5] END C=5, multi_class=ovr, solver=liblinear;, score=(train=0.859, test=0.854) total time=   0.1s
# [CV 1/5] END C=10, multi_class=auto, solver=newton-cg;, score=(train=0.875, test=0.873) total time=   0.2s
# [CV 2/5] END C=10, multi_class=auto, solver=newton-cg;, score=(train=0.876, test=0.868) total time=   0.2s
# [CV 3/5] END C=10, multi_class=auto, solver=newton-cg;, score=(train=0.876, test=0.859) total time=   0.2s
# [CV 4/5] END C=10, multi_class=auto, solver=newton-cg;, score=(train=0.869, test=0.885) total time=   0.2s
# [CV 5/5] END C=10, multi_class=auto, solver=newton-cg;, score=(train=0.874, test=0.871) total time=   0.2s
# [CV 1/5] END C=10, multi_class=auto, solver=liblinear;, score=(train=0.863, test=0.871) total time=   0.1s
# [CV 2/5] END C=10, multi_class=auto, solver=liblinear;, score=(train=0.867, test=0.853) total time=   0.1s
# [CV 3/5] END C=10, multi_class=auto, solver=liblinear;, score=(train=0.868, test=0.849) total time=   0.1s
# [CV 4/5] END C=10, multi_class=auto, solver=liblinear;, score=(train=0.859, test=0.877) total time=   0.1s
# [CV 5/5] END C=10, multi_class=auto, solver=liblinear;, score=(train=0.867, test=0.863) total time=   0.1s
# [CV 1/5] END C=10, multi_class=ovr, solver=newton-cg;, score=(train=0.863, test=0.870) total time=   0.1s
# [CV 2/5] END C=10, multi_class=ovr, solver=newton-cg;, score=(train=0.866, test=0.850) total time=   0.1s
# [CV 3/5] END C=10, multi_class=ovr, solver=newton-cg;, score=(train=0.866, test=0.850) total time=   0.2s
# [CV 4/5] END C=10, multi_class=ovr, solver=newton-cg;, score=(train=0.860, test=0.874) total time=   0.1s
# [CV 5/5] END C=10, multi_class=ovr, solver=newton-cg;, score=(train=0.865, test=0.864) total time=   0.1s
# [CV 1/5] END C=10, multi_class=ovr, solver=liblinear;, score=(train=0.863, test=0.871) total time=   0.1s
# [CV 2/5] END C=10, multi_class=ovr, solver=liblinear;, score=(train=0.867, test=0.853) total time=   0.1s
# [CV 3/5] END C=10, multi_class=ovr, solver=liblinear;, score=(train=0.868, test=0.849) total time=   0.1s
# [CV 4/5] END C=10, multi_class=ovr, solver=liblinear;, score=(train=0.859, test=0.877) total time=   0.1s
# [CV 5/5] END C=10, multi_class=ovr, solver=liblinear;, score=(train=0.867, test=0.863) total time=   0.1s
# [CV 1/5] END C=50, multi_class=auto, solver=newton-cg;, score=(train=0.886, test=0.879) total time=   0.3s
# [CV 2/5] END C=50, multi_class=auto, solver=newton-cg;, score=(train=0.885, test=0.873) total time=   0.3s
# [CV 3/5] END C=50, multi_class=auto, solver=newton-cg;, score=(train=0.888, test=0.873) total time=   0.3s
# [CV 4/5] END C=50, multi_class=auto, solver=newton-cg;, score=(train=0.881, test=0.897) total time=   0.3s
# [CV 5/5] END C=50, multi_class=auto, solver=newton-cg;, score=(train=0.883, test=0.878) total time=   0.3s
# [CV 1/5] END C=50, multi_class=auto, solver=liblinear;, score=(train=0.877, test=0.875) total time=   0.1s
# [CV 2/5] END C=50, multi_class=auto, solver=liblinear;, score=(train=0.878, test=0.870) total time=   0.1s
# [CV 3/5] END C=50, multi_class=auto, solver=liblinear;, score=(train=0.879, test=0.862) total time=   0.1s
# [CV 4/5] END C=50, multi_class=auto, solver=liblinear;, score=(train=0.870, test=0.890) total time=   0.1s
# [CV 5/5] END C=50, multi_class=auto, solver=liblinear;, score=(train=0.876, test=0.870) total time=   0.1s
# [CV 1/5] END C=50, multi_class=ovr, solver=newton-cg;, score=(train=0.877, test=0.876) total time=   0.1s
# [CV 2/5] END C=50, multi_class=ovr, solver=newton-cg;, score=(train=0.877, test=0.870) total time=   0.2s
# [CV 3/5] END C=50, multi_class=ovr, solver=newton-cg;, score=(train=0.879, test=0.864) total time=   0.2s
# [CV 4/5] END C=50, multi_class=ovr, solver=newton-cg;, score=(train=0.869, test=0.890) total time=   0.1s
# [CV 5/5] END C=50, multi_class=ovr, solver=newton-cg;, score=(train=0.877, test=0.870) total time=   0.2s
# [CV 1/5] END C=50, multi_class=ovr, solver=liblinear;, score=(train=0.877, test=0.875) total time=   0.1s
# [CV 2/5] END C=50, multi_class=ovr, solver=liblinear;, score=(train=0.878, test=0.870) total time=   0.1s
# [CV 3/5] END C=50, multi_class=ovr, solver=liblinear;, score=(train=0.879, test=0.862) total time=   0.1s
# [CV 4/5] END C=50, multi_class=ovr, solver=liblinear;, score=(train=0.870, test=0.890) total time=   0.1s
# [CV 5/5] END C=50, multi_class=ovr, solver=liblinear;, score=(train=0.876, test=0.870) total time=   0.1s
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'C': [1, 5, 10, 50], 'multi_class': ['auto', 'ovr'],
#                          'solver': ['newton-cg', 'liblinear']},
#              return_train_score=True, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 50, 'multi_class': 'auto', 'solver': 'newton-cg'}
# 0.880187395786872

# %%
#Dinnara
predictions = grid.predict(X_test_scaled)

# %%
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['FALSE POSITIVE' 'CANDIDATE' 'FALSE POSITIVE' 'CANDIDATE' 'CANDIDATE'
#  'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CANDIDATE'
#  'FALSE POSITIVE']
# First 10 Actual labels: ['FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE', 'CANDIDATE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE', 'FALSE POSITIVE']

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=y_names))
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.79      0.65      0.71       324
# FALSE POSITIVE       0.72      0.81      0.77       345
#      CANDIDATE       0.98      1.00      0.99       730
#
#       accuracy                           0.87      1399
#      macro avg       0.83      0.82      0.82      1399
#   weighted avg       0.87      0.87      0.87      1399

# %%
results = pd.DataFrame(grid.cv_results_)
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.128616      0.008825         0.000856        0.000027       1
# 1        0.039854      0.002605         0.000887        0.000043       1
# 2        0.111047      0.028315         0.001179        0.000497       1
# 3        0.038608      0.000413         0.000869        0.000047       1
# 4        0.168140      0.007288         0.000845        0.000022       5
# 5        0.053900      0.002251         0.000908        0.000064       5
# 6        0.109529      0.012792         0.000869        0.000020       5
# 7        0.052126      0.000790         0.000916        0.000098       5
# 8        0.205397      0.015352         0.000923        0.000061      10
# 9        0.060945      0.001656         0.000892        0.000065      10
# 10       0.142022      0.020460         0.001115        0.000507      10
# 11       0.065274      0.004771         0.000862        0.000051      10
# 12       0.291821      0.020193         0.000873        0.000010      50
# 13       0.094339      0.008716         0.000891        0.000046      50
# 14       0.162180      0.022209         0.001184        0.000381      50
# 15       0.092942      0.006921         0.000877        0.000051      50
#
#    param_multi_class param_solver  \
# 0               auto    newton-cg
# 1               auto    liblinear
# 2                ovr    newton-cg
# 3                ovr    liblinear
# 4               auto    newton-cg
# 5               auto    liblinear
# 6                ovr    newton-cg
# 7                ovr    liblinear
# 8               auto    newton-cg
# 9               auto    liblinear
# 10               ovr    newton-cg
# 11               ovr    liblinear
# 12              auto    newton-cg
# 13              auto    liblinear
# 14               ovr    newton-cg
# 15               ovr    liblinear
#
#                                                params  split0_test_score  \
# 0   {'C': 1, 'multi_class': 'auto', 'solver': 'new...           0.852547
# 1   {'C': 1, 'multi_class': 'auto', 'solver': 'lib...           0.843610
# 2   {'C': 1, 'multi_class': 'ovr', 'solver': 'newt...           0.840036
# 3   {'C': 1, 'multi_class': 'ovr', 'solver': 'libl...           0.843610
# 4   {'C': 5, 'multi_class': 'auto', 'solver': 'new...           0.873101
# 5   {'C': 5, 'multi_class': 'auto', 'solver': 'lib...           0.865058
# 6   {'C': 5, 'multi_class': 'ovr', 'solver': 'newt...           0.864164
# 7   {'C': 5, 'multi_class': 'ovr', 'solver': 'libl...           0.865058
# 8   {'C': 10, 'multi_class': 'auto', 'solver': 'ne...           0.873101
# 9   {'C': 10, 'multi_class': 'auto', 'solver': 'li...           0.871314
# 10  {'C': 10, 'multi_class': 'ovr', 'solver': 'new...           0.869526
# 11  {'C': 10, 'multi_class': 'ovr', 'solver': 'lib...           0.871314
# 12  {'C': 50, 'multi_class': 'auto', 'solver': 'ne...           0.879357
# 13  {'C': 50, 'multi_class': 'auto', 'solver': 'li...           0.874888
# 14  {'C': 50, 'multi_class': 'ovr', 'solver': 'new...           0.875782
# 15  {'C': 50, 'multi_class': 'ovr', 'solver': 'lib...           0.874888
#
#     split1_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0            0.844504  ...         0.848891        0.005450               13
# 1            0.835567  ...         0.837982        0.005985               15
# 2            0.834674  ...         0.838341        0.006274               14
# 3            0.835567  ...         0.837982        0.005985               15
# 4            0.861483  ...         0.866416        0.009030                6
# 5            0.850760  ...         0.856938        0.007594               10
# 6            0.844504  ...         0.855866        0.009290               12
# 7            0.850760  ...         0.856938        0.007594               10
# 8            0.867739  ...         0.871066        0.008394                5
# 9            0.852547  ...         0.862482        0.010599                7
# 10           0.849866  ...         0.861410        0.009980                9
# 11           0.852547  ...         0.862482        0.010599                7
# 12           0.873101  ...         0.880187        0.008870                1
# 13           0.869526  ...         0.873391        0.009230                3
# 14           0.869526  ...         0.873927        0.008848                2
# 15           0.869526  ...         0.873391        0.009230                3
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0             0.847977            0.849989            0.851810
# 1             0.839705            0.839928            0.840411
# 2             0.839258            0.841046            0.843317
# 3             0.839705            0.839928            0.840411
# 4             0.865638            0.868992            0.869468
# 5             0.855354            0.858261            0.859186
# 6             0.855578            0.858484            0.858516
# 7             0.855354            0.858261            0.859186
# 8             0.875028            0.875922            0.876173
# 9             0.862508            0.867203            0.867680
# 10            0.863179            0.866085            0.866115
# 11            0.862508            0.867203            0.867680
# 12            0.886206            0.884865            0.887573
# 13            0.877264            0.877711            0.878632
# 14            0.877040            0.876593            0.878632
# 15            0.877264            0.877711            0.878632
#
#     split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0             0.846893            0.849352          0.849204         0.001690
# 1             0.836388            0.839070          0.839101         0.001423
# 2             0.835941            0.840635          0.840039         0.002430
# 3             0.836388            0.839070          0.839101         0.001423
# 4             0.863210            0.866786          0.866819         0.002287
# 5             0.852481            0.858963          0.856849         0.002578
# 6             0.852257            0.858069          0.856581         0.002420
# 7             0.852481            0.858963          0.856849         0.002578
# 8             0.869468            0.873715          0.874061         0.002453
# 9             0.859410            0.866786          0.864717         0.003234
# 10            0.859857            0.865445          0.864136         0.002394
# 11            0.859410            0.866786          0.864717         0.003234
# 12            0.881091            0.883326          0.884612         0.002255
# 13            0.869692            0.875503          0.875760         0.003200
# 14            0.869245            0.876844          0.875671         0.003291
# 15            0.869692            0.875503          0.875760         0.003200
#
# [16 rows x 23 columns]

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-7ffc35e2dc82> in <module>
#       5 import joblib
#       6 filename = 'your_name.sav'
# ----> 7 joblib.dump(your_model, filename)
#
# NameError: name 'your_model' is not defined
