# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0   54.418383     2.479000e-04    -2.479000e-04
# 1                 0   19.899140     1.490000e-05    -1.490000e-05
# 2                 0    1.736952     2.630000e-07    -2.630000e-07
# 3                 0    2.525592     3.760000e-06    -3.760000e-06
# 4                 0    4.134435     1.050000e-05    -1.050000e-05
# ...             ...         ...              ...              ...
# 6986              1    8.589871     1.846000e-04    -1.846000e-04
# 6987              0    0.527699     1.160000e-07    -1.160000e-07
# 6988              0    1.739849     1.780000e-05    -1.780000e-05
# 6989              0    0.681402     2.430000e-06    -2.430000e-06
# 6990              1    4.856035     6.360000e-05    -6.360000e-05
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  \
# 0      162.513840          0.003520  ...             -81      4.467
# 1      175.850252          0.000581  ...            -176      4.544
# 2      170.307565          0.000115  ...            -174      4.564
# 3      171.595550          0.001130  ...            -211      4.438
# 4      172.979370          0.001900  ...            -232      4.486
# ...           ...               ...  ...             ...        ...
# 6986   132.016100          0.015700  ...            -152      4.296
# 6987   131.705093          0.000170  ...            -166      4.529
# 6988   133.001270          0.007690  ...            -220      4.444
# 6989   132.181750          0.002850  ...            -236      4.447
# 6990   135.993300          0.010800  ...            -225      4.385
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0              0.064          -0.096     0.927          0.105         -0.061
# 1              0.044          -0.176     0.868          0.233         -0.078
# 2              0.053          -0.168     0.791          0.201         -0.067
# 3              0.070          -0.210     1.046          0.334         -0.133
# 4              0.054          -0.229     0.972          0.315         -0.105
# ...              ...             ...       ...            ...            ...
# 6986           0.231          -0.189     1.088          0.313         -0.228
# 6987           0.035          -0.196     0.903          0.237         -0.079
# 6988           0.056          -0.224     1.031          0.341         -0.114
# 6989           0.056          -0.224     1.041          0.341         -0.114
# 6990           0.054          -0.216     1.193          0.410         -0.137
#
#              ra        dec  koi_kepmag
# 0     291.93423  48.141651      15.347
# 1     297.00482  48.134129      15.436
# 2     285.53461  48.285210      15.597
# 3     288.75488  48.226200      15.509
# 4     296.28613  48.224670      15.714
# ...         ...        ...         ...
# 6986  298.74921  46.973351      14.478
# 6987  297.18875  47.093819      14.082
# 6988  286.50937  47.163219      14.757
# 6989  294.16489  47.176281      15.385
# 6990  297.00977  47.121021      14.826
#
# [6991 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
#selected_features = df.drop(['koi_disposition'], axis = 1)
X = df.drop(['koi_disposition'], axis = 1)
X.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
y = df['koi_disposition']
y_names = ['CONFIRMED','FALSE POSITIVE','CANDIDATE']
y.head()
# Out:
# 0         CONFIRMED
# 1    FALSE POSITIVE
# 2    FALSE POSITIVE
# 3         CONFIRMED
# 4         CONFIRMED
# Name: koi_disposition, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((5592, 40), (1399, 40), (5592,), (1399,))

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6661              0              0              0              0    3.848222
# 5871              0              1              0              0    4.028671
# 817               0              0              1              0    1.008917
# 6718              0              0              1              0    3.060260
# 6163              1              0              0              0    2.668111
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6661     1.660000e-05    -1.660000e-05   131.918500          0.003510
# 5871     4.390000e-07    -4.390000e-07   133.954215          0.000091
# 817      2.130000e-06    -2.130000e-06   354.859260          0.001440
# 6718     4.050000e-05    -4.050000e-05   132.762000          0.010100
# 6163     6.750000e-05    -6.750000e-05   133.507100          0.022200
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6661         -0.003510  ...             -83      4.323           0.105
# 5871         -0.000091  ...            -208      4.168           0.190
# 817          -0.001440  ...            -189      4.578           0.040
# 6718         -0.010100  ...            -176      4.426           0.087
# 6163         -0.022200  ...            -266      4.164           0.174
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6661          -0.116     1.193          0.198         -0.148  286.25443
# 5871          -0.190     1.528          0.472         -0.387  292.22934
# 817           -0.160     0.795          0.195         -0.065  297.50385
# 6718          -0.203     1.010          0.291         -0.125  298.13965
# 6163          -0.174     1.561          0.897         -0.389  295.69476
#
#             dec  koi_kepmag
# 6661  41.021870      14.919
# 5871  44.160789      13.775
# 817   40.342972      15.360
# 6718  41.417229      14.255
# 6163  45.529202      13.688
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_scaled = X_minmax.transform(X_train)
X_test_scaled = X_minmax.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='liblinear', random_state=0, multi_class ='ovr')

# %%
classifier.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(multi_class='ovr', random_state=0, solver='liblinear')

# %%
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8412017167381974
# Testing Data Score: 0.8384560400285919

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model

from sklearn.model_selection import GridSearchCV
param_grid = {'C': [5, 10, 50], 
              'solver' : ['newton-cg', 'liblinear'],
              'multi_class' : ['auto', 'ovr'] }
    
grid = GridSearchCV(classifier, param_grid, verbose=3, return_train_score=True)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END C=5, multi_class=auto, solver=newton-cg;, score=(train=0.868, test=0.864) total time=   0.2s
# [CV 2/5] END C=5, multi_class=auto, solver=newton-cg;, score=(train=0.864, test=0.865) total time=   0.2s
# [CV 3/5] END C=5, multi_class=auto, solver=newton-cg;, score=(train=0.868, test=0.869) total time=   0.2s
# [CV 4/5] END C=5, multi_class=auto, solver=newton-cg;, score=(train=0.870, test=0.858) total time=   0.2s
# [CV 5/5] END C=5, multi_class=auto, solver=newton-cg;, score=(train=0.865, test=0.869) total time=   0.2s
# [CV 1/5] END C=5, multi_class=auto, solver=liblinear;, score=(train=0.855, test=0.853) total time=   0.1s
# [CV 2/5] END C=5, multi_class=auto, solver=liblinear;, score=(train=0.856, test=0.847) total time=   0.1s
# [CV 3/5] END C=5, multi_class=auto, solver=liblinear;, score=(train=0.856, test=0.857) total time=   0.1s
# [CV 4/5] END C=5, multi_class=auto, solver=liblinear;, score=(train=0.859, test=0.848) total time=   0.1s
# [CV 5/5] END C=5, multi_class=auto, solver=liblinear;, score=(train=0.857, test=0.855) total time=   0.1s
# [CV 1/5] END C=5, multi_class=ovr, solver=newton-cg;, score=(train=0.856, test=0.855) total time=   0.2s
# [CV 2/5] END C=5, multi_class=ovr, solver=newton-cg;, score=(train=0.855, test=0.850) total time=   0.1s
# [CV 3/5] END C=5, multi_class=ovr, solver=newton-cg;, score=(train=0.855, test=0.858) total time=   0.2s
# [CV 4/5] END C=5, multi_class=ovr, solver=newton-cg;, score=(train=0.859, test=0.849) total time=   0.1s
# [CV 5/5] END C=5, multi_class=ovr, solver=newton-cg;, score=(train=0.855, test=0.857) total time=   0.1s
# [CV 1/5] END C=5, multi_class=ovr, solver=liblinear;, score=(train=0.855, test=0.853) total time=   0.1s
# [CV 2/5] END C=5, multi_class=ovr, solver=liblinear;, score=(train=0.856, test=0.847) total time=   0.1s
# [CV 3/5] END C=5, multi_class=ovr, solver=liblinear;, score=(train=0.856, test=0.857) total time=   0.1s
# [CV 4/5] END C=5, multi_class=ovr, solver=liblinear;, score=(train=0.859, test=0.848) total time=   0.1s
# [CV 5/5] END C=5, multi_class=ovr, solver=liblinear;, score=(train=0.857, test=0.855) total time=   0.1s
# [CV 1/5] END C=10, multi_class=auto, solver=newton-cg;, score=(train=0.873, test=0.873) total time=   0.2s
# [CV 2/5] END C=10, multi_class=auto, solver=newton-cg;, score=(train=0.872, test=0.868) total time=   0.2s
# [CV 3/5] END C=10, multi_class=auto, solver=newton-cg;, score=(train=0.874, test=0.871) total time=   0.2s
# [CV 4/5] END C=10, multi_class=auto, solver=newton-cg;, score=(train=0.878, test=0.864) total time=   0.2s
# [CV 5/5] END C=10, multi_class=auto, solver=newton-cg;, score=(train=0.872, test=0.874) total time=   0.2s
# [CV 1/5] END C=10, multi_class=auto, solver=liblinear;, score=(train=0.866, test=0.863) total time=   0.1s
# [CV 2/5] END C=10, multi_class=auto, solver=liblinear;, score=(train=0.863, test=0.861) total time=   0.1s
# [CV 3/5] END C=10, multi_class=auto, solver=liblinear;, score=(train=0.866, test=0.865) total time=   0.1s
# [CV 4/5] END C=10, multi_class=auto, solver=liblinear;, score=(train=0.868, test=0.855) total time=   0.1s
# [CV 5/5] END C=10, multi_class=auto, solver=liblinear;, score=(train=0.861, test=0.869) total time=   0.1s
# [CV 1/5] END C=10, multi_class=ovr, solver=newton-cg;, score=(train=0.865, test=0.863) total time=   0.2s
# [CV 2/5] END C=10, multi_class=ovr, solver=newton-cg;, score=(train=0.862, test=0.861) total time=   0.1s
# [CV 3/5] END C=10, multi_class=ovr, solver=newton-cg;, score=(train=0.866, test=0.866) total time=   0.1s
# [CV 4/5] END C=10, multi_class=ovr, solver=newton-cg;, score=(train=0.867, test=0.854) total time=   0.1s
# [CV 5/5] END C=10, multi_class=ovr, solver=newton-cg;, score=(train=0.862, test=0.869) total time=   0.1s
# [CV 1/5] END C=10, multi_class=ovr, solver=liblinear;, score=(train=0.866, test=0.863) total time=   0.1s
# [CV 2/5] END C=10, multi_class=ovr, solver=liblinear;, score=(train=0.863, test=0.861) total time=   0.1s
# [CV 3/5] END C=10, multi_class=ovr, solver=liblinear;, score=(train=0.866, test=0.865) total time=   0.1s
# [CV 4/5] END C=10, multi_class=ovr, solver=liblinear;, score=(train=0.868, test=0.855) total time=   0.1s
# [CV 5/5] END C=10, multi_class=ovr, solver=liblinear;, score=(train=0.861, test=0.869) total time=   0.1s
# [CV 1/5] END C=50, multi_class=auto, solver=newton-cg;, score=(train=0.879, test=0.886) total time=   0.3s
# [CV 2/5] END C=50, multi_class=auto, solver=newton-cg;, score=(train=0.883, test=0.875) total time=   0.3s
# [CV 3/5] END C=50, multi_class=auto, solver=newton-cg;, score=(train=0.880, test=0.886) total time=   0.3s
# [CV 4/5] END C=50, multi_class=auto, solver=newton-cg;, score=(train=0.886, test=0.869) total time=   0.3s
# [CV 5/5] END C=50, multi_class=auto, solver=newton-cg;, score=(train=0.882, test=0.875) total time=   0.3s
# [CV 1/5] END C=50, multi_class=auto, solver=liblinear;, score=(train=0.875, test=0.876) total time=   0.1s
# [CV 2/5] END C=50, multi_class=auto, solver=liblinear;, score=(train=0.875, test=0.875) total time=   0.1s
# [CV 3/5] END C=50, multi_class=auto, solver=liblinear;, score=(train=0.876, test=0.875) total time=   0.1s
# [CV 4/5] END C=50, multi_class=auto, solver=liblinear;, score=(train=0.881, test=0.864) total time=   0.1s
# [CV 5/5] END C=50, multi_class=auto, solver=liblinear;, score=(train=0.875, test=0.872) total time=   0.1s
# [CV 1/5] END C=50, multi_class=ovr, solver=newton-cg;, score=(train=0.874, test=0.878) total time=   0.2s
# [CV 2/5] END C=50, multi_class=ovr, solver=newton-cg;, score=(train=0.875, test=0.873) total time=   0.1s
# [CV 3/5] END C=50, multi_class=ovr, solver=newton-cg;, score=(train=0.875, test=0.873) total time=   0.2s
# [CV 4/5] END C=50, multi_class=ovr, solver=newton-cg;, score=(train=0.881, test=0.864) total time=   0.2s
# [CV 5/5] END C=50, multi_class=ovr, solver=newton-cg;, score=(train=0.875, test=0.873) total time=   0.2s
# [CV 1/5] END C=50, multi_class=ovr, solver=liblinear;, score=(train=0.875, test=0.876) total time=   0.1s
# [CV 2/5] END C=50, multi_class=ovr, solver=liblinear;, score=(train=0.875, test=0.875) total time=   0.1s
# [CV 3/5] END C=50, multi_class=ovr, solver=liblinear;, score=(train=0.876, test=0.875) total time=   0.1s
# [CV 4/5] END C=50, multi_class=ovr, solver=liblinear;, score=(train=0.881, test=0.864) total time=   0.1s
# [CV 5/5] END C=50, multi_class=ovr, solver=liblinear;, score=(train=0.875, test=0.872) total time=   0.1s
# GridSearchCV(estimator=LogisticRegression(multi_class='ovr', random_state=0,
#                                           solver='liblinear'),
#              param_grid={'C': [5, 10, 50], 'multi_class': ['auto', 'ovr'],
#                          'solver': ['newton-cg', 'liblinear']},
#              return_train_score=True, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 50, 'multi_class': 'auto', 'solver': 'newton-cg'}
# 0.8780392664674727

# %%
predictions = grid.predict(X_test_scaled)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=y_names))
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.83      0.69      0.76       367
# FALSE POSITIVE       0.71      0.85      0.78       332
#      CANDIDATE       0.99      0.99      0.99       700
#
#       accuracy                           0.88      1399
#      macro avg       0.85      0.84      0.84      1399
#   weighted avg       0.89      0.88      0.88      1399

# %% [markdown]
# # Save the Model

# %%
import joblib
filename = 'Dinnara_Hitt_Logistic_Regression.sav'
joblib.dump(classifier, filename)
# Out:
# ['Dinnara_Hitt_Logistic_Regression.sav']
